# %%
import re
import pandas as pd
import os
from openai import OpenAI

# OpenAI API 키 설정
api_key = "your-key"
client = OpenAI(api_key=api_key)

# 사용자 이름을 자동으로 가져오기
username = os.getlogin()

# 바탕화면 경로 설정
desktop_path = os.path.join(os.path.expanduser('~'), 'Desktop')

# 대봉공급처 폴더 경로 설정
supplier_folder = os.path.join(desktop_path, '대봉공급처', '도매A-026')

# 엑셀 파일 이름
file_name = '0604_대봉_견적서.xlsx'
file_path = os.path.join(supplier_folder, file_name)

def read_excel(file_path):
    """엑셀 파일을 읽고 DataFrame을 반환"""
    df = pd.read_excel(file_path)
    return df.to_csv(index=False)

def call_gpt_function(data):
    """OpenAI ChatCompletion API를 호출하여 데이터를 변환"""
    messages = [
        {"role": "system", "content": """
            You are an expert in transforming Excel data into a 2D list format.
            Please provide the data as a 2D list in Python list format based on the given structure.
            Columns to consider:
            - A: Option Name
            - B: KG
            - C: Size Info and Number of Fruits
            - E: Price Including Delivery
            - G: Weight Per Size
            Example output:
            [
                ['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'],
                ['WholesaleA-026', 'Option A', '1kg', '6000', 'Small/15 units/Each 65g']
            ]
        """},
        {"role": "user", "content": data}
    ]
    functions = [
        {
            "name": "transform_excel_data",
            "description": "Transforms Excel CSV data to a 2D list.",
            "parameters": {
                "type": "object",
                "properties": {
                    "data": {
                        "type": "string",
                        "description": "The CSV data from the Excel file"
                    }
                },
                "required": ["data"]
            }
        }
    ]
    
    response = client.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        functions=functions,
        function_call="auto"
    )
    
    return response

def clean_gpt_output(output):
    # GPT 출력에서 불필요한 부분을 제거하고 올바른 리스트 형식으로 변환
    cleaned_output = output.strip()
    # 리스트 형식을 올바르게 닫아줌
    if cleaned_output.count('[') > cleaned_output.count(']'):
        cleaned_output += ']'
    return cleaned_output

try:
    # 엑셀 파일 열기
    excel_file = pd.ExcelFile(file_path)
    
    # 모든 시트의 이름 확인
    sheet_names = excel_file.sheet_names
    print("시트 이름:", sheet_names)

    # 각 시트를 읽어 데이터프레임으로 변환
    dataframes = {}
    output_data = []

    for sheet_name in sheet_names:
        excel_content = ""
        df = pd.read_excel(excel_file, sheet_name=sheet_name)
        dataframes[sheet_name] = df
        excel_content += f"Sheet: {sheet_name}\n"
        excel_content += df.to_string(index=False)
        excel_content += "\n\n"
        
        gpt_output = gpt_transformTest(excel_content)
        cleaned_output = clean_gpt_output(gpt_output)
        output_data.append(cleaned_output)
        print("GPT Output:", cleaned_output)  # GPT 원시 출력 확인

    # GPT 출력 데이터를 2차원 리스트 형식으로 변환
    data = []
    for output in output_data:
        print("Raw GPT output before parsing:", output)  # 파싱 전 출력 확인
        data.append(output)  # GPT 출력값을 그대로 2차원 리스트에 저장

    # 변환된 데이터 출력
    for item in data:
        print(item)

except FileNotFoundError:
    print("파일을 찾을 수 없습니다. 경로를 확인하세요.")
except pd.errors.EmptyDataError:
    print("파일에 데이터가 없습니다.")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")

# 데이터를 2차원 리스트로 변환하는 함수
def parse_gpt_output(data):
    parsed_data = []
    for item in data:
        # 문자열에서 리스트 형식을 추출
        match = re.search(r"\[.*?\]", item)
        if match:
            # 문자열을 실제 리스트로 변환
            try:
                parsed_list = eval(match.group())
                parsed_data.append(parsed_list)
            except SyntaxError as e:
                print(f"SyntaxError while parsing: {e}")
                print(f"Problematic output: {match.group()}")
    return parsed_data

# 데이터 파싱
parsed_data = parse_gpt_output(data)

# 파싱된 데이터 출력
for row in parsed_data:
    print(row)

# %%
# print(type(data))
# print(type(data[1]))
# print(type(parse_gpt_output(data[1])))
# print(parse_gpt_output(data))
# print(data[1])
# print(data)

new_list = []
for value in data:
    print(value)
    new_value = parse_gpt_output(value)
    print(new_value)
    new_list.append(new_value)

print(new_list)
for i in new_list:
    print(type(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       1 # print(type(data))
#       2 # print(type(data[1]))
#       3 # print(type(parse_gpt_output(data[1])))
#       4 # print(parse_gpt_output(data))
#       5 # print(data[1])
#       6 # print(data)
#       8 new_list = []
# ----> 9 for value in data:
#      10     print(value)
#      11     new_value = parse_gpt_output(value)
#
# NameError: name 'data' is not defined

# %%
import os
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google.auth.transport.requests import Request
import os.path
import json
import pickle
import requests

def oauth():
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
    creds_filename = 'test-daebong-service-account.json'  # 서비스 계정 파일 경로를 지정합니다.

    # 서비스 계정 파일을 사용하여 인증 정보를 로드합니다.
    creds = service_account.Credentials.from_service_account_file(creds_filename, scopes=SCOPES)
    return creds

def oauthByWeb():
    # 필요한 스코프를 지정합니다.
    SCOPES = [
        'https://www.googleapis.com/auth/spreadsheets',
        'https://www.googleapis.com/auth/script.projects',
        "https://www.googleapis.com/auth/script.scriptapp",
        'https://www.googleapis.com/auth/drive',
        'https://www.googleapis.com/auth/drive.file'
    ]
    creds = None
    # 'token.json' 파일이 존재하면, 저장된 인증 정보를 불러옵니다.
    if os.path.exists('token.json'):
        with open('token.json', 'rb') as token:
            creds = pickle.load(token)

    # 저장된 인증 정보가 없거나, 유효하지 않은 경우 새로운 인증을 진행합니다.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            creds_filename = 'oauth-app-script.json'
            flow = InstalledAppFlow.from_client_secrets_file(creds_filename, SCOPES)
            creds = flow.run_local_server(port=8080)
        # 새로운 인증 정보를 'token.json'에 저장합니다.
        with open('token.json', 'wb') as token:
            pickle.dump(creds, token)

    return creds

def append_crawling_data(service, spreadsheet_id, values, sheet_name):
    # 데이터를 추가할 범위 설정
    range_name = f'{sheet_name}!E2:k100'

    body = {
        'values': values
    }

    # 스프레드시트에 데이터 추가
    result = service.spreadsheets().values().append(
        spreadsheetId=spreadsheet_id, range=range_name,
        valueInputOption='RAW', body=body, insertDataOption='INSERT_ROWS').execute()

    print(result)

def update_spreadsheet(array_2d):
    creds = oauthByWeb()
    service_sheets = build('sheets', 'v4', credentials=creds)
    product_sheet_id = "1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg"
    sheet_name = "test기존업체신규품목"
    append_crawling_data(service_sheets, product_sheet_id, array_2d, sheet_name)
    print("완료")
# if __name__ == "__main__":
#     creds = oauthByWeb()
#     service_sheets = build('sheets', 'v4', credentials=creds)
#     product_sheet_id = "1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg"
#     sheet_name = "기존업체신규품목"
#     append_crawling_data(service_sheets, product_sheet_id, data, sheet_name)

#      # 데이터를 100행씩 분할하여 전송
#     chunk_size = 10
#     for i in range(0, len(data), chunk_size):
#         chunk = data[i:i + chunk_size]
#         append_crawling_data(service_sheets, product_sheet_id, chunk, sheet_name)

# %%
def run_conversation(excel_data):
    # Step 1: send the conversation and available functions to the model
    messages = [ {"role": "system", "content": """
            You are an expert in transforming Excel data into a 2D list format.
            Please provide the data as a 2D list in Python list format based on the given structure.
            Columns to consider:
            - A: Option Name
            - B: KG
            - C: Size Info and Number of Fruits
            - E: Price Including Delivery
            - G: Weight Per Size
            Example output:
            [
                ['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'],
                ['WholesaleA-026', 'Option A', '1kg', '6000', 'Small/15 units/Each 65g']
            ]
        """},
        {"role": "user", "content": excel_data}]
    tools = [
        {
            "type": "function",
            "function": {
                "name": "update_spreadsheet",
                "description": "엑셀에서 정확하게 다음과 같은 형식으로 데이터를 뽑아내는 거야.",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "array_2d": {
                            "type": "array",
                            "items": {
                                "type": "array",
                                "items": {
                                    "type": "string",
                                    "description": "fruite option"
                                }
                            },
                            "description": "A 2D array of fruite option"
                        },
                    },
                    "required": ["array_2d"],
                },
            },
        }
    ]
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        tools=tools
    )
    response_message = response.choices[0].message
     # Accessing tool_call
    tool_call = response.choices[0].message.tool_calls[0]
    print("response.choices[0]")
    print(response.choices[0])
    print("tool_call")
    print(tool_call)
    
    if tool_call:
        # Only process the first tool call
        function_name = tool_call.function.name
        print("function_name")
        print(function_name)
        function_args = json.loads(tool_call.function.arguments)
        print("function_args")
        print(function_args)
        print(function_args.get("array_2d"))
        update_spreadsheet(function_args.get("array_2d"))
        function_response = update_spreadsheet(
            array_2d=function_args.get("array_2d"),
        )

        print("response_message")
        # print(response_message)
        messages.append(response_message)  # Extend conversation with assistant's reply
        messages.append(
            {
                "role": "tool",
                "name": function_name,
                "content": function_response,
            }
        )  # Extend conversation with function response
        # second_response = client.chat.completions.create(
        #     model="gpt-3.5-turbo",
        #     messages=messages,
        # )  # Get a new response from the model where it can see the function response
        return "complete"

# %%
import re
import pandas as pd
import os
from openai import OpenAI

# OpenAI API 키 설정
api_key = "your-key"
client = OpenAI(api_key=api_key)

# 주어진 경로
base_path = "/Users/baegmingi/daebong/daebong-automation/product-upload"

# # 사용자 이름을 자동으로 가져오기
# username = os.getlogin()

# # 대봉공급처 폴더 경로 설정
# supplier_folder = os.path.join(base_path, ".")

# 엑셀 파일 이름
file_name = '0604_대봉_견적서.xlsx'
file_path = os.path.join(base_path, file_name)
def read_excel(file_path):
    """엑셀 파일을 읽고 DataFrame을 반환"""
    df = pd.read_excel(file_path)
    return df.to_csv(index=False)

try:
    # 엑셀 파일 열기
    excel_file = pd.ExcelFile(file_path)
    
    # 모든 시트의 이름 확인
    sheet_names = excel_file.sheet_names
    print("시트 이름:", sheet_names)

    # 각 시트를 읽어 데이터프레임으로 변환
    dataframes = {}
    output_data = []

    for sheet_name in sheet_names:
        print(sheet_name)
        excel_content = ""
        df = pd.read_excel(excel_file, sheet_name=sheet_name)
        dataframes[sheet_name] = df
        excel_content += f"Sheet: {sheet_name}\n"
        excel_content += df.to_string(index=False)
        excel_content += "\n\n"
        # print(excel_content)
        gpt_output = run_conversation(excel_content)

        # cleaned_output = clean_gpt_output(gpt_output)
        # output_data.append(cleaned_output)
        # print("GPT Output:", cleaned_output)  # GPT 원시 출력 확인

    # GPT 출력 데이터를 2차원 리스트 형식으로 변환
    # data = []
    # for output in output_data:
    #     print("Raw GPT output before parsing:", output)  # 파싱 전 출력 확인
    #     data.append(output)  # GPT 출력값을 그대로 2차원 리스트에 저장

    # # 변환된 데이터 출력
    # for item in data:
    #     print(item)

except FileNotFoundError as e:
    print(f"파일을 찾을 수 없습니다. 경로를 확인하세요.: {e}")
except pd.errors.EmptyDataError:
    print("파일에 데이터가 없습니다.")
except Exception as e:
    print(f"오류가 발생했습니다: {e}")
# Out:
# 시트 이름: ['견적서', '신비 복숭아', '신선 복숭아', '천도 복숭아', '자두', '대극천(반납작 복숭아)', '하우스 수박', '하우스 복숭아', '참외', '백자메론', '가정용 사과', '완숙토마토', '샐러드채소', '청양고추', '일반 파프리카', '오이고추', '백오이', '가시오이', '당근', '양파', '감자', '비트', '다진마늘', '대추']
# 견적서
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_DiG66R9keF70c7cpbWJyTBT4', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","Option A","1kg","6000","Small/15 units/Each 65g"]]}', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_DiG66R9keF70c7cpbWJyTBT4', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","Option A","1kg","6000","Small/15 units/Each 65g"]]}', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', 'Option A', '1kg', '6000', 'Small/15 units/Each 65g']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', 'Option A', '1kg', '6000', 'Small/15 units/Each 65g']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E2:I3", 'updatedRows': 2, 'updatedColumns': 5, 'updatedCells': 10}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I3", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E4:I5", 'updatedRows': 2, 'updatedColumns': 5, 'updatedCells': 10}}
# 완료
# response_message
# 신비 복숭아
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_VFARXtljQPS5WybYKY6FaTfC', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","신비 1kg","1kg","9200","Small/15 units/Each 65g"],["WholesaleA-027","신비 1.5kg","1.5kg","13200","Small/23 units/Each 75g"],["WholesaleA-028","신비 2kg","2kg","16200","Small/30 units/Each 65g"]]}', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_VFARXtljQPS5WybYKY6FaTfC', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","신비 1kg","1kg","9200","Small/15 units/Each 65g"],["WholesaleA-027","신비 1.5kg","1.5kg","13200","Small/23 units/Each 75g"],["WholesaleA-028","신비 2kg","2kg","16200","Small/30 units/Each 65g"]]}', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', '신비 1kg', '1kg', '9200', 'Small/15 units/Each 65g'], ['WholesaleA-027', '신비 1.5kg', '1.5kg', '13200', 'Small/23 units/Each 75g'], ['WholesaleA-028', '신비 2kg', '2kg', '16200', 'Small/30 units/Each 65g']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', '신비 1kg', '1kg', '9200', 'Small/15 units/Each 65g'], ['WholesaleA-027', '신비 1.5kg', '1.5kg', '13200', 'Small/23 units/Each 75g'], ['WholesaleA-028', '신비 2kg', '2kg', '16200', 'Small/30 units/Each 65g']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I5", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E6:I9", 'updatedRows': 4, 'updatedColumns': 5, 'updatedCells': 20}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I9", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E10:I13", 'updatedRows': 4, 'updatedColumns': 5, 'updatedCells': 20}}
# 완료
# response_message
# 신선 복숭아
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_EmKXXtsfiw9o2gKduCu4U8qe', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","Option A","1kg","6900","Small/15 units/Each 65g"],["WholesaleA-027","Option B","1kg","8600","Medium Small/13 units"],["WholesaleA-028","Option C","1kg","9000","Medium/11 units"],["WholesaleA-029","Option D","1kg","9700","Medium Large/9 units"],["WholesaleA-030","Option E","1kg","10200","Large/7 units"],["WholesaleA-031","Option F","1.5kg","10800","Small/23 units"],["WholesaleA-032","Option G","1.5kg","12400","Medium Small/20 units"],["WholesaleA-033","Option H","1.5kg","12900","Medium/17 units"],["WholesaleA-034","Option I","1.5kg","14000","Medium Large/14 units"],["WholesaleA-035","Option J","1.5kg","14500","Large/11 units"],["WholesaleA-036","Option K","2kg","10500","Small/30 units"],["WholesaleA-037","Option L","2kg","15200","Medium Small/26 units"],["WholesaleA-038","Option M","2kg","15800","Medium/22 units"],["WholesaleA-039","Option N","2kg","17300","Medium Large/18 units"],["WholesaleA-040","Option O","2kg","18000","Large/14 units"]]}', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_EmKXXtsfiw9o2gKduCu4U8qe', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","Option A","1kg","6900","Small/15 units/Each 65g"],["WholesaleA-027","Option B","1kg","8600","Medium Small/13 units"],["WholesaleA-028","Option C","1kg","9000","Medium/11 units"],["WholesaleA-029","Option D","1kg","9700","Medium Large/9 units"],["WholesaleA-030","Option E","1kg","10200","Large/7 units"],["WholesaleA-031","Option F","1.5kg","10800","Small/23 units"],["WholesaleA-032","Option G","1.5kg","12400","Medium Small/20 units"],["WholesaleA-033","Option H","1.5kg","12900","Medium/17 units"],["WholesaleA-034","Option I","1.5kg","14000","Medium Large/14 units"],["WholesaleA-035","Option J","1.5kg","14500","Large/11 units"],["WholesaleA-036","Option K","2kg","10500","Small/30 units"],["WholesaleA-037","Option L","2kg","15200","Medium Small/26 units"],["WholesaleA-038","Option M","2kg","15800","Medium/22 units"],["WholesaleA-039","Option N","2kg","17300","Medium Large/18 units"],["WholesaleA-040","Option O","2kg","18000","Large/14 units"]]}', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', 'Option A', '1kg', '6900', 'Small/15 units/Each 65g'], ['WholesaleA-027', 'Option B', '1kg', '8600', 'Medium Small/13 units'], ['WholesaleA-028', 'Option C', '1kg', '9000', 'Medium/11 units'], ['WholesaleA-029', 'Option D', '1kg', '9700', 'Medium Large/9 units'], ['WholesaleA-030', 'Option E', '1kg', '10200', 'Large/7 units'], ['WholesaleA-031', 'Option F', '1.5kg', '10800', 'Small/23 units'], ['WholesaleA-032', 'Option G', '1.5kg', '12400', 'Medium Small/20 units'], ['WholesaleA-033', 'Option H', '1.5kg', '12900', 'Medium/17 units'], ['WholesaleA-034', 'Option I', '1.5kg', '14000', 'Medium Large/14 units'], ['WholesaleA-035', 'Option J', '1.5kg', '14500', 'Large/11 units'], ['WholesaleA-036', 'Option K', '2kg', '10500', 'Small/30 units'], ['WholesaleA-037', 'Option L', '2kg', '15200', 'Medium Small/26 units'], ['WholesaleA-038', 'Option M', '2kg', '15800', 'Medium/22 units'], ['WholesaleA-039', 'Option N', '2kg', '17300', 'Medium Large/18 units'], ['WholesaleA-040', 'Option O', '2kg', '18000', 'Large/14 units']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', 'Option A', '1kg', '6900', 'Small/15 units/Each 65g'], ['WholesaleA-027', 'Option B', '1kg', '8600', 'Medium Small/13 units'], ['WholesaleA-028', 'Option C', '1kg', '9000', 'Medium/11 units'], ['WholesaleA-029', 'Option D', '1kg', '9700', 'Medium Large/9 units'], ['WholesaleA-030', 'Option E', '1kg', '10200', 'Large/7 units'], ['WholesaleA-031', 'Option F', '1.5kg', '10800', 'Small/23 units'], ['WholesaleA-032', 'Option G', '1.5kg', '12400', 'Medium Small/20 units'], ['WholesaleA-033', 'Option H', '1.5kg', '12900', 'Medium/17 units'], ['WholesaleA-034', 'Option I', '1.5kg', '14000', 'Medium Large/14 units'], ['WholesaleA-035', 'Option J', '1.5kg', '14500', 'Large/11 units'], ['WholesaleA-036', 'Option K', '2kg', '10500', 'Small/30 units'], ['WholesaleA-037', 'Option L', '2kg', '15200', 'Medium Small/26 units'], ['WholesaleA-038', 'Option M', '2kg', '15800', 'Medium/22 units'], ['WholesaleA-039', 'Option N', '2kg', '17300', 'Medium Large/18 units'], ['WholesaleA-040', 'Option O', '2kg', '18000', 'Large/14 units']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I13", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E14:I29", 'updatedRows': 16, 'updatedColumns': 5, 'updatedCells': 80}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I29", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E30:I45", 'updatedRows': 16, 'updatedColumns': 5, 'updatedCells': 80}}
# 완료
# response_message
# 천도 복숭아
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_V8LB6iTGpb8K4leEPRkYAlLt', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","Option A","1kg","6000","Small/15 units/Each 65g"]]}', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_V8LB6iTGpb8K4leEPRkYAlLt', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","Option A","1kg","6000","Small/15 units/Each 65g"]]}', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', 'Option A', '1kg', '6000', 'Small/15 units/Each 65g']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', 'Option A', '1kg', '6000', 'Small/15 units/Each 65g']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I45", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E46:I47", 'updatedRows': 2, 'updatedColumns': 5, 'updatedCells': 10}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I47", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E48:I49", 'updatedRows': 2, 'updatedColumns': 5, 'updatedCells': 10}}
# 완료
# response_message
# 자두
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Eqb2d9zzbzdwsQbfCnJ1ZbL9', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","하우스 자두 소과 / 300g x 1팩 (팩당 7-9과)","1kg","7600","Small/7-9 fruits/Pack of 300g"],["WholesaleA-027","하우스 자두 소과 / 300g x 2팩 (팩당 7-9과)","1kg","13000","Small/7-9 fruits/Pack of 300g x 2"],["WholesaleA-028","하우스 자두 소과 / 300g x 3팩 (팩당 7-9과)","1kg","17300","Small/7-9 fruits/Pack of 300g x 3"],["WholesaleA-029","하우스 자두 소과 / 300g x 5팩 (팩당 7-9과)","1kg","25900","Small/7-9 fruits/Pack of 300g x 5"],["WholesaleA-030","하우스 자두 중과 / 300g x 1팩 (팩당 4-6과)","1kg","8700","Medium/4-6 fruits/Pack of 300g"],["WholesaleA-031","하우스 자두 중과 / 300g x 2팩 (팩당 4-6과)","1kg","15100","Medium/4-6 fruits/Pack of 300g x 2"],["WholesaleA-032","하우스 자두 중과 / 300g x 3팩 (팩당 4-6과)","1kg","20500","Medium/4-6 fruits/Pack of 300g x 3"],["WholesaleA-033","하우스 자두 중과 / 300g x 5팩 (팩당 4-6과)","1kg","31200","Medium/4-6 fruits/Pack of 300g x 5"],["WholesaleA-034","노지 자두 소과 / 30과 내외","1kg","11200","Small/30 fruits/Pack of 1kg"],["WholesaleA-035","노지 자두 중과 / 22과 내외","1kg","12200","Medium/22 fruits/Pack of 1kg"],["WholesaleA-036","노지 자두 대과 / 15과 내외","1kg","13300","Large/15 fruits/Pack of 1kg"],["WholesaleA-037","노지 자두 소과 / 45과 내외","1.5kg","16200","Small/45 fruits/Pack of 1.5kg"],["WholesaleA-038","노지 자두 중과 / 33과 내외","1.5kg","17800","Medium/33 fruits/Pack of 1.5kg"],["WholesaleA-039","노지 자두 대과 / 22과 내외","1.5kg","19500","Large/22 fruits/Pack of 1.5kg"],["WholesaleA-040","노지 자두 소과 / 60과 내외","2kg","20000","Small/60 fruits/Pack of 2kg"],["WholesaleA-041","노지 자두 중과 / 44과 내외","2kg","22300","Medium/44 fruits/Pack of 2kg"],["WholesaleA-042","노지 자두 대과 / 30과 내외","2kg","24500","Large/30 fruits/Pack of 2kg"]]}', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_Eqb2d9zzbzdwsQbfCnJ1ZbL9', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","하우스 자두 소과 / 300g x 1팩 (팩당 7-9과)","1kg","7600","Small/7-9 fruits/Pack of 300g"],["WholesaleA-027","하우스 자두 소과 / 300g x 2팩 (팩당 7-9과)","1kg","13000","Small/7-9 fruits/Pack of 300g x 2"],["WholesaleA-028","하우스 자두 소과 / 300g x 3팩 (팩당 7-9과)","1kg","17300","Small/7-9 fruits/Pack of 300g x 3"],["WholesaleA-029","하우스 자두 소과 / 300g x 5팩 (팩당 7-9과)","1kg","25900","Small/7-9 fruits/Pack of 300g x 5"],["WholesaleA-030","하우스 자두 중과 / 300g x 1팩 (팩당 4-6과)","1kg","8700","Medium/4-6 fruits/Pack of 300g"],["WholesaleA-031","하우스 자두 중과 / 300g x 2팩 (팩당 4-6과)","1kg","15100","Medium/4-6 fruits/Pack of 300g x 2"],["WholesaleA-032","하우스 자두 중과 / 300g x 3팩 (팩당 4-6과)","1kg","20500","Medium/4-6 fruits/Pack of 300g x 3"],["WholesaleA-033","하우스 자두 중과 / 300g x 5팩 (팩당 4-6과)","1kg","31200","Medium/4-6 fruits/Pack of 300g x 5"],["WholesaleA-034","노지 자두 소과 / 30과 내외","1kg","11200","Small/30 fruits/Pack of 1kg"],["WholesaleA-035","노지 자두 중과 / 22과 내외","1kg","12200","Medium/22 fruits/Pack of 1kg"],["WholesaleA-036","노지 자두 대과 / 15과 내외","1kg","13300","Large/15 fruits/Pack of 1kg"],["WholesaleA-037","노지 자두 소과 / 45과 내외","1.5kg","16200","Small/45 fruits/Pack of 1.5kg"],["WholesaleA-038","노지 자두 중과 / 33과 내외","1.5kg","17800","Medium/33 fruits/Pack of 1.5kg"],["WholesaleA-039","노지 자두 대과 / 22과 내외","1.5kg","19500","Large/22 fruits/Pack of 1.5kg"],["WholesaleA-040","노지 자두 소과 / 60과 내외","2kg","20000","Small/60 fruits/Pack of 2kg"],["WholesaleA-041","노지 자두 중과 / 44과 내외","2kg","22300","Medium/44 fruits/Pack of 2kg"],["WholesaleA-042","노지 자두 대과 / 30과 내외","2kg","24500","Large/30 fruits/Pack of 2kg"]]}', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', '하우스 자두 소과 / 300g x 1팩 (팩당 7-9과)', '1kg', '7600', 'Small/7-9 fruits/Pack of 300g'], ['WholesaleA-027', '하우스 자두 소과 / 300g x 2팩 (팩당 7-9과)', '1kg', '13000', 'Small/7-9 fruits/Pack of 300g x 2'], ['WholesaleA-028', '하우스 자두 소과 / 300g x 3팩 (팩당 7-9과)', '1kg', '17300', 'Small/7-9 fruits/Pack of 300g x 3'], ['WholesaleA-029', '하우스 자두 소과 / 300g x 5팩 (팩당 7-9과)', '1kg', '25900', 'Small/7-9 fruits/Pack of 300g x 5'], ['WholesaleA-030', '하우스 자두 중과 / 300g x 1팩 (팩당 4-6과)', '1kg', '8700', 'Medium/4-6 fruits/Pack of 300g'], ['WholesaleA-031', '하우스 자두 중과 / 300g x 2팩 (팩당 4-6과)', '1kg', '15100', 'Medium/4-6 fruits/Pack of 300g x 2'], ['WholesaleA-032', '하우스 자두 중과 / 300g x 3팩 (팩당 4-6과)', '1kg', '20500', 'Medium/4-6 fruits/Pack of 300g x 3'], ['WholesaleA-033', '하우스 자두 중과 / 300g x 5팩 (팩당 4-6과)', '1kg', '31200', 'Medium/4-6 fruits/Pack of 300g x 5'], ['WholesaleA-034', '노지 자두 소과 / 30과 내외', '1kg', '11200', 'Small/30 fruits/Pack of 1kg'], ['WholesaleA-035', '노지 자두 중과 / 22과 내외', '1kg', '12200', 'Medium/22 fruits/Pack of 1kg'], ['WholesaleA-036', '노지 자두 대과 / 15과 내외', '1kg', '13300', 'Large/15 fruits/Pack of 1kg'], ['WholesaleA-037', '노지 자두 소과 / 45과 내외', '1.5kg', '16200', 'Small/45 fruits/Pack of 1.5kg'], ['WholesaleA-038', '노지 자두 중과 / 33과 내외', '1.5kg', '17800', 'Medium/33 fruits/Pack of 1.5kg'], ['WholesaleA-039', '노지 자두 대과 / 22과 내외', '1.5kg', '19500', 'Large/22 fruits/Pack of 1.5kg'], ['WholesaleA-040', '노지 자두 소과 / 60과 내외', '2kg', '20000', 'Small/60 fruits/Pack of 2kg'], ['WholesaleA-041', '노지 자두 중과 / 44과 내외', '2kg', '22300', 'Medium/44 fruits/Pack of 2kg'], ['WholesaleA-042', '노지 자두 대과 / 30과 내외', '2kg', '24500', 'Large/30 fruits/Pack of 2kg']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', '하우스 자두 소과 / 300g x 1팩 (팩당 7-9과)', '1kg', '7600', 'Small/7-9 fruits/Pack of 300g'], ['WholesaleA-027', '하우스 자두 소과 / 300g x 2팩 (팩당 7-9과)', '1kg', '13000', 'Small/7-9 fruits/Pack of 300g x 2'], ['WholesaleA-028', '하우스 자두 소과 / 300g x 3팩 (팩당 7-9과)', '1kg', '17300', 'Small/7-9 fruits/Pack of 300g x 3'], ['WholesaleA-029', '하우스 자두 소과 / 300g x 5팩 (팩당 7-9과)', '1kg', '25900', 'Small/7-9 fruits/Pack of 300g x 5'], ['WholesaleA-030', '하우스 자두 중과 / 300g x 1팩 (팩당 4-6과)', '1kg', '8700', 'Medium/4-6 fruits/Pack of 300g'], ['WholesaleA-031', '하우스 자두 중과 / 300g x 2팩 (팩당 4-6과)', '1kg', '15100', 'Medium/4-6 fruits/Pack of 300g x 2'], ['WholesaleA-032', '하우스 자두 중과 / 300g x 3팩 (팩당 4-6과)', '1kg', '20500', 'Medium/4-6 fruits/Pack of 300g x 3'], ['WholesaleA-033', '하우스 자두 중과 / 300g x 5팩 (팩당 4-6과)', '1kg', '31200', 'Medium/4-6 fruits/Pack of 300g x 5'], ['WholesaleA-034', '노지 자두 소과 / 30과 내외', '1kg', '11200', 'Small/30 fruits/Pack of 1kg'], ['WholesaleA-035', '노지 자두 중과 / 22과 내외', '1kg', '12200', 'Medium/22 fruits/Pack of 1kg'], ['WholesaleA-036', '노지 자두 대과 / 15과 내외', '1kg', '13300', 'Large/15 fruits/Pack of 1kg'], ['WholesaleA-037', '노지 자두 소과 / 45과 내외', '1.5kg', '16200', 'Small/45 fruits/Pack of 1.5kg'], ['WholesaleA-038', '노지 자두 중과 / 33과 내외', '1.5kg', '17800', 'Medium/33 fruits/Pack of 1.5kg'], ['WholesaleA-039', '노지 자두 대과 / 22과 내외', '1.5kg', '19500', 'Large/22 fruits/Pack of 1.5kg'], ['WholesaleA-040', '노지 자두 소과 / 60과 내외', '2kg', '20000', 'Small/60 fruits/Pack of 2kg'], ['WholesaleA-041', '노지 자두 중과 / 44과 내외', '2kg', '22300', 'Medium/44 fruits/Pack of 2kg'], ['WholesaleA-042', '노지 자두 대과 / 30과 내외', '2kg', '24500', 'Large/30 fruits/Pack of 2kg']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I49", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E50:I67", 'updatedRows': 18, 'updatedColumns': 5, 'updatedCells': 90}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I67", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E68:I85", 'updatedRows': 18, 'updatedColumns': 5, 'updatedCells': 90}}
# 완료
# response_message
# 대극천(반납작 복숭아)
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_8arsaZ3KNvq3479AEIQbKPqe', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","대극천","1kg","16500","Small/11-14 fruits/Each 70-90g"],["WholesaleA-027","대극천","1kg","20500","Medium/6-10 fruits/Each 100-150g"]]}', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_8arsaZ3KNvq3479AEIQbKPqe', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["WholesaleA-026","대극천","1kg","16500","Small/11-14 fruits/Each 70-90g"],["WholesaleA-027","대극천","1kg","20500","Medium/6-10 fruits/Each 100-150g"]]}', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', '대극천', '1kg', '16500', 'Small/11-14 fruits/Each 70-90g'], ['WholesaleA-027', '대극천', '1kg', '20500', 'Medium/6-10 fruits/Each 100-150g']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['WholesaleA-026', '대극천', '1kg', '16500', 'Small/11-14 fruits/Each 70-90g'], ['WholesaleA-027', '대극천', '1kg', '20500', 'Medium/6-10 fruits/Each 100-150g']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I85", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E86:I88", 'updatedRows': 3, 'updatedColumns': 5, 'updatedCells': 15}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I88", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E89:I91", 'updatedRows': 3, 'updatedColumns': 5, 'updatedCells': 15}}
# 완료
# response_message
# 하우스 수박
# response.choices[0]
# Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_sswMVjt7V78OMyoQcW1B4Y0z', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["하우스 수박","가정용","3kg 내외","10800","Small/품절/수박 전용 에어셀 포장 중량 오차 범위 5%가량 있습니다 출고지: 영천 더자인 물류센터"],["하우스 수박","","4kg 내외","11800","Small/품절/"],["하우스 수박","","5kg 내외","13000","Small/품절/"],["하우스 수박","","6kg 내외","15000","Small/15000/"],["하우스 수박","","7kg 내외","16000","Small/16000/"],["하우스 수박","","8kg 내외","17000","Small/신규/"]] }', name='update_spreadsheet'), type='function')]))
# tool_call
# ChatCompletionMessageToolCall(id='call_sswMVjt7V78OMyoQcW1B4Y0z', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["하우스 수박","가정용","3kg 내외","10800","Small/품절/수박 전용 에어셀 포장 중량 오차 범위 5%가량 있습니다 출고지: 영천 더자인 물류센터"],["하우스 수박","","4kg 내외","11800","Small/품절/"],["하우스 수박","","5kg 내외","13000","Small/품절/"],["하우스 수박","","6kg 내외","15000","Small/15000/"],["하우스 수박","","7kg 내외","16000","Small/16000/"],["하우스 수박","","8kg 내외","17000","Small/신규/"]] }', name='update_spreadsheet'), type='function')
# function_name
# update_spreadsheet
# function_args
# {'array_2d': [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['하우스 수박', '가정용', '3kg 내외', '10800', 'Small/품절/수박 전용 에어셀 포장 중량 오차 범위 5%가량 있습니다 출고지: 영천 더자인 물류센터'], ['하우스 수박', '', '4kg 내외', '11800', 'Small/품절/'], ['하우스 수박', '', '5kg 내외', '13000', 'Small/품절/'], ['하우스 수박', '', '6kg 내외', '15000', 'Small/15000/'], ['하우스 수박', '', '7kg 내외', '16000', 'Small/16000/'], ['하우스 수박', '', '8kg 내외', '17000', 'Small/신규/']]}
# [['Supplier Code', 'Option Name', 'KG', 'Price Including Delivery', 'Size/Number of Fruits/Weight Per Size'], ['하우스 수박', '가정용', '3kg 내외', '10800', 'Small/품절/수박 전용 에어셀 포장 중량 오차 범위 5%가량 있습니다 출고지: 영천 더자인 물류센터'], ['하우스 수박', '', '4kg 내외', '11800', 'Small/품절/'], ['하우스 수박', '', '5kg 내외', '13000', 'Small/품절/'], ['하우스 수박', '', '6kg 내외', '15000', 'Small/15000/'], ['하우스 수박', '', '7kg 내외', '16000', 'Small/16000/'], ['하우스 수박', '', '8kg 내외', '17000', 'Small/신규/']]
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I91", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E92:I98", 'updatedRows': 7, 'updatedColumns': 5, 'updatedCells': 35}}
# 완료
# {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'tableRange': "'test기존업체신규품목'!E1:I98", 'updates': {'spreadsheetId': '1cKe3qTX_C7qYqSDJvR3ab1LJFAVOMOfkDXFuL3OKNPg', 'updatedRange': "'test기존업체신규품목'!E99:I105", 'updatedRows': 7, 'updatedColumns': 5, 'updatedCells': 35}}
# 완료
# response_message
# 하우스 복숭아
# response.choices[0]
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ZSv26OOU6yJbqp5GJLYEfl3h', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["하우스 복숭아","Option A","1kg","17500","Small/7-9 fruits/Each"],"하우스 복숭아","Option B","1.5kg","25800","Small/11-14 fruits/Each"],"하우스 복숭아 Option C, 1.5 kg, 31200, Medium/6-10 fruits/Each, 원산지: 김천\\" " \n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n  \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\n\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t  \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t                                                                                               \n\t\t\t\t\t\t\t\t\t\n\t       \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\n    \t \t\t\t\t\t\t\t\t\t  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\n    \t  \n\t        \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\n       \t\t                                                                                                                                                                            \t \t\t\t\t\t\t\t\t\t\n\n    \t   \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n     \t\n  \t\n       \t\t\t\t\t\t\t\t\t \n   \t\t\t\t\t\t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \n  \n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n     \n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\n  \t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n  \n  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n   \t\n\t\n\t\t\t\t\t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\n\n\n\n\t      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\t\n  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\n\n\n\n\n   \n   \t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\n   \t\n   \t\n   \n\t\n\n\n\n\n\t\t\t\t\n\t\t\t\t\n\n\n\t\t\t\t\t\t\t\t\t\t\n       \n\n\t\n       \n\t\n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t    \n   \t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\n  \t\t\t\t\n   \n   \t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t\n    \n       \n\t\n    \n   \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \n   \t\t\t\t\t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n      \n    \n   \n   \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\ ...
# tool_call
# ChatCompletionMessageToolCall(id='call_ZSv26OOU6yJbqp5GJLYEfl3h', function=Function(arguments='{"array_2d":[["Supplier Code","Option Name","KG","Price Including Delivery","Size/Number of Fruits/Weight Per Size"],["하우스 복숭아","Option A","1kg","17500","Small/7-9 fruits/Each"],"하우스 복숭아","Option B","1.5kg","25800","Small/11-14 fruits/Each"],"하우스 복숭아 Option C, 1.5 kg, 31200, Medium/6-10 fruits/Each, 원산지: 김천\\" " \n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n  \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\n\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t  \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t                                                                                               \n\t\t\t\t\t\t\t\t\t\n\t       \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\n    \t \t\t\t\t\t\t\t\t\t  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\n    \t  \n\t        \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\n       \t\t                                                                                                                                                                            \t \t\t\t\t\t\t\t\t\t\n\n    \t   \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n     \t\n  \t\n       \t\t\t\t\t\t\t\t\t \n   \t\t\t\t\t\t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \n  \n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n     \n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\n  \t\t\t\t\t\n    \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n  \n  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n   \t\n\t\n\t\t\t\t\t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\t\n\n\n\n\t      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\t\n  \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\n\n\n\n\n   \n   \t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\n   \t\n   \t\n   \n\t\n\n\n\n\n\t\t\t\t\n\t\t\t\t\n\n\n\t\t\t\t\t\t\t\t\t\t\n       \n\n\t\n       \n\t\n     \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t    \n   \t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\t\n  \t\t\t\t\n   \n   \t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t\n    \n       \n\t\n    \n   \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \n   \t\t\t\t\t\t\t\t\n      \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n      \n    \n   \n   \t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n   \t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n    \t\t\t\t\t\n\n   \n   \t\t\t\t\ ...
# function_name
# update_spreadsheet
# 오류가 발생했습니다: Expecting ':' delimiter: line 217 column 49 (char 4364)
