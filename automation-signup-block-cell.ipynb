# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google.auth.transport.requests import Request
import os.path
import json




def oauth():
    SCOPES = ['https://www.googleapis.com/auth/spreadsheets']
    creds_filename = 'test-daebong-service-account.json'  # 서비스 계정 파일 경로를 지정합니다.

    # 서비스 계정 파일을 사용하여 인증 정보를 로드합니다.
    creds = service_account.Credentials.from_service_account_file(creds_filename, scopes=SCOPES)
    return creds



def apply_formula_to_cells(service, spreadsheet_id, sheet_title, new_daebong_spreadsheet_title):
    range_name = f"{sheet_title}!J11:J"  # J열 11행부터 끝까지
    # formula = f'=IF(LEN(E11)=0,"", {new_daebong_spreadsheet_title})'  # 적용할 수식
   

    formulas = []
    for i in range(11, 1011):  # 11행부터 1010행까지
        formula = f'=IF(LEN(E{i})=0,"", {new_daebong_spreadsheet_title})'
        formulas.append([formula])

    value_range_body = {
        'values': formulas
    }

    request = service.spreadsheets().values().update(spreadsheetId=spreadsheet_id, range=range_name, valueInputOption='USER_ENTERED', body=value_range_body)
    request.execute()

# %%
import time


def blockSpecificCell(service, spreadsheet_id):
    # 스프레드시트의 메타데이터에서 sheet_id 가져오기

    spreadsheet = service.spreadsheets().get(spreadsheetId=spreadsheet_id).execute()
    sheets = spreadsheet.get('sheets', '')

    sheet_order_id = None
    sheet_accumulated_order_id = None
    for sheet in sheets:
        if sheet.get('properties', {}).get('title', '') == "발주서":
            sheet_order_id = sheet.get('properties', {}).get('sheetId', '')

        if sheet.get('properties', {}).get('title', '') == "누적발주":
            sheet_accumulated_order_id = sheet.get('properties', {}).get('sheetId', '')


    user_emails = ["daebong10x@gmail.com", "test-daebong@newdaebong.iam.gserviceaccount.com"]

    if sheet_order_id is not None:
        # 보호된 범위 설정
        requests = [
            {
                'addProtectedRange': {
                    'protectedRange': {
                        'range': {
                            'sheetId': sheet_order_id,
                            'startRowIndex': 10,  # 11행부터 시작 (0 기반 인덱스)
                            'startColumnIndex': 9,  # J열 (0 기반 인덱스)
                            # endRowIndex, endColumnIndex를 생략하면 범위의 나머지 부분을 포함합니다.
                        },
                        'description': 'Protected cells',
                        'editors': {
                            'users': user_emails,  # 이 셀을 편집할 수 있는 사용자
                        }
                    }
                }
            },
            {
                'addProtectedRange': {
                    'protectedRange': {
                        'range': {
                            'sheetId': sheet_accumulated_order_id,
                            'startRowIndex': 0,  # 11행부터 시작 (0 기반 인덱스)
                            'startColumnIndex': 0,  # J열 (0 기반 인덱스)
                            # endRowIndex, endColumnIndex를 생략하면 범위의 나머지 부분을 포함합니다.
                        },
                        'description': 'Protected cells',
                        'editors': {
                            'users': user_emails,  # 이 셀을 편집할 수 있는 사용자
                        }
                    }
                }
            }
        ]

        body = {
            'requests': requests
        }

        response = service.spreadsheets().batchUpdate(
            spreadsheetId=spreadsheet_id,
            body=body
        ).execute()

        print(response)

# %%
import time

if __name__ == "__main__":
    creds = oauth()
    service = build('sheets', 'v4', credentials=creds)
    array = [
        [226
        ,'1-J6V0nLHQlxLA8PbTiTXaGt08VlqGv5fo3kfaH35FJE'],
        [227
        ,'14KS38kY_hZD2061EmIaAm3cA3Rw9R2mEDoIczxdk3sQ'],
        [228, 
        "1hrmwW1aznOQJewXDlyCsfCqEvsTjh_BXXVSZAqwH2r0"],
        [229,
        "1aEZw4wsj1HXCuxvcc5mnvJ0UI8Qkuo05-zmYPzblSWc"],
        [229,
        "1s8u-mN8fv4_OCg5tfQrAktGMFiFipZxu6qSSQh120KE"],
        [230,
        "18KC58d7RZl9wkzTb6qxBeOlVitldqRfO0lJ5uchwV2s"],
        [230,
        "1OxaNX2XUK5CTsqseH6Dnj_3Bhi1FNn_79YAAH1sOdhE"],
        [231,
        "1CC5HAoulfHpomxSJWU2Zr0doNLwZQYj9uMsnk9YlUIY"],
        [231,
        "1IHElKAeGzOK0-LRR3kHsJl-ttKO2_0BL_MApwrozW8A"],
        [232,
        "1iKJnf9JCFOvBUqcufaX9xs2YVrqIpVGTxFruIP6wwhg"],
        [233,
        "1911UP9nR65fxxJO_Na8886T-Q-FBPvMaRs-twm4KsoI"],
        [234,
        "13gTVm1GQEnrQqgc_Q55M8cWyrWrUAmt2gt_v7Ltm-18"],
        [235,
        "1wKg9_xHUVFRujWUsX9unEN38pD8yg3B_c1f8z1C8FI4"],
        [236,
        "102YTIjanaJqeckd-zJ_s5d-EgUeZQUB1F7G9wWw_-6w"],
        [237,
        "1P3Z7nF8kRh0H84yk26Y3G4EzfY_AWRPdU4mNyppTNaM"],
        [238,
        "1ywXZQV6GXPP-xDAfAJ1Q0AqBD4TTTV214qOvUF79_aI"],
        [239,
        "1hAdI2qGPe1UIV-8qPLBGOk2XLvSwub0LSEQBJSL4XXE"],
    ]

    for i in array:
        # apply_formula_to_cells(service, i[1], '발주서', i[0])
        time.sleep(10)  # 10초 동안 프로그램을 일시 중지합니다.
        blockSpecificCell(service, i[1])
# Out:
# {'spreadsheetId': '1-J6V0nLHQlxLA8PbTiTXaGt08VlqGv5fo3kfaH35FJE', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1808056591, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 263388760, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '14KS38kY_hZD2061EmIaAm3cA3Rw9R2mEDoIczxdk3sQ', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 948000289, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 893034913, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1hrmwW1aznOQJewXDlyCsfCqEvsTjh_BXXVSZAqwH2r0', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 272074121, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1033335702, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1aEZw4wsj1HXCuxvcc5mnvJ0UI8Qkuo05-zmYPzblSWc', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1749086409, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 238168191, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1s8u-mN8fv4_OCg5tfQrAktGMFiFipZxu6qSSQh120KE', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1986706540, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1452443744, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '18KC58d7RZl9wkzTb6qxBeOlVitldqRfO0lJ5uchwV2s', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 26153847, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1054743105, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1OxaNX2XUK5CTsqseH6Dnj_3Bhi1FNn_79YAAH1sOdhE', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 2101361573, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 162929835, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1CC5HAoulfHpomxSJWU2Zr0doNLwZQYj9uMsnk9YlUIY', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 159527628, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1125453143, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1IHElKAeGzOK0-LRR3kHsJl-ttKO2_0BL_MApwrozW8A', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1683347788, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1311355612, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1iKJnf9JCFOvBUqcufaX9xs2YVrqIpVGTxFruIP6wwhg', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1462207962, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 992056542, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1911UP9nR65fxxJO_Na8886T-Q-FBPvMaRs-twm4KsoI', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1068029504, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1727023109, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '13gTVm1GQEnrQqgc_Q55M8cWyrWrUAmt2gt_v7Ltm-18', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1992337131, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 108939563, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1wKg9_xHUVFRujWUsX9unEN38pD8yg3B_c1f8z1C8FI4', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 879671326, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 879880601, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '102YTIjanaJqeckd-zJ_s5d-EgUeZQUB1F7G9wWw_-6w', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1561703494, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 376248073, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1P3Z7nF8kRh0H84yk26Y3G4EzfY_AWRPdU4mNyppTNaM', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 1323071726, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1633118781, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1ywXZQV6GXPP-xDAfAJ1Q0AqBD4TTTV214qOvUF79_aI', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 724831103, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 1666693118, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}
# {'spreadsheetId': '1hAdI2qGPe1UIV-8qPLBGOk2XLvSwub0LSEQBJSL4XXE', 'replies': [{'addProtectedRange': {'protectedRange': {'protectedRangeId': 340814626, 'range': {'sheetId': 1464675013, 'startRowIndex': 10, 'startColumnIndex': 9}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}, {'addProtectedRange': {'protectedRange': {'protectedRangeId': 2147246296, 'range': {'sheetId': 701874974, 'startRowIndex': 0, 'startColumnIndex': 0}, 'description': 'Protected cells', 'requestingUserCanEdit': True, 'editors': {'users': ['daebong10x@gmail.com', 'test-daebong@newdaebong.iam.gserviceaccount.com']}}}}]}

# %%
if __name__ == "__main__":
    # 여기에 스프레드시트 ID와 가져오고 싶은 범위를 지정합니다.
    
    creds = oauth()
    service = build('sheets', 'v4', credentials=creds)
    new_spreadsheet_id = "1gR3kForAN5hNpmA4HBf3_xRS62FtAbSLyKBvWKAUgHg"

    array = [
        [226
        ,'1-J6V0nLHQlxLA8PbTiTXaGt08VlqGv5fo3kfaH35FJE'],
        [227
        ,'14KS38kY_hZD2061EmIaAm3cA3Rw9R2mEDoIczxdk3sQ'],
        [228, 
        "1hrmwW1aznOQJewXDlyCsfCqEvsTjh_BXXVSZAqwH2r0"],
        [229,
        "1aEZw4wsj1HXCuxvcc5mnvJ0UI8Qkuo05-zmYPzblSWc"],
        [229,
        "1s8u-mN8fv4_OCg5tfQrAktGMFiFipZxu6qSSQh120KE"],
        [230,
        "18KC58d7RZl9wkzTb6qxBeOlVitldqRfO0lJ5uchwV2s"],
        [230,
        "1OxaNX2XUK5CTsqseH6Dnj_3Bhi1FNn_79YAAH1sOdhE"],
        [231,
        "1CC5HAoulfHpomxSJWU2Zr0doNLwZQYj9uMsnk9YlUIY"],
        [231,
        "1IHElKAeGzOK0-LRR3kHsJl-ttKO2_0BL_MApwrozW8A"],
        [232,
        "1iKJnf9JCFOvBUqcufaX9xs2YVrqIpVGTxFruIP6wwhg"],
        [233,
        "1911UP9nR65fxxJO_Na8886T-Q-FBPvMaRs-twm4KsoI"],
        [234,
        "13gTVm1GQEnrQqgc_Q55M8cWyrWrUAmt2gt_v7Ltm-18"],
        [235,
        "1wKg9_xHUVFRujWUsX9unEN38pD8yg3B_c1f8z1C8FI4"],
        [236,
        "102YTIjanaJqeckd-zJ_s5d-EgUeZQUB1F7G9wWw_-6w"],
        [237,
        "1P3Z7nF8kRh0H84yk26Y3G4EzfY_AWRPdU4mNyppTNaM"],
        [238,
        "1ywXZQV6GXPP-xDAfAJ1Q0AqBD4TTTV214qOvUF79_aI"],
        [239,
        "1hAdI2qGPe1UIV-8qPLBGOk2XLvSwub0LSEQBJSL4XXE"],
    ]

    for i in array:
        apply_formula_to_cells(service, i[1], '발주서', i[0])
